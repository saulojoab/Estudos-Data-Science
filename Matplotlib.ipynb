# %% [markdown]
# # Estudo de Matplotlib - Saulo Joab
# Esse notebook será dedicado aos meus estudos com <b>matplotlib</b> e provavelmente <b>numpy</b>.
#
# Caso precise, entre em contato comigo [aqui](http://github.com/saulojoab) ou [aqui](http://linkedin.com/in/saulojoab).

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np

# %%
# ESTUDANDO MATPLOTLIB
# GRÁFICO DE LINHA
x = [1, 2, 5]
y = [2, 3, 7]

# Título.
plt.title("Meu primeiro gráfico!");

# Eixos.
plt.xlabel("Eixo X");
plt.ylabel("Eixo Y");

# Precisa de x e y.
plt.plot(x, y);

# Mostrando.
plt.show();

# %%
# GRÁFICO DE BARRAS
x = [1, 2, 3, 4, 5];
y = [3, 6, 2, 1, 4];

# Legendas.
plt.title("Gráfico de Barras");

plt.xlabel("Eixo X");
plt.ylabel("Eixo Y");

# Plotando o gráfico de barras.
plt.bar(x, y);
plt.show();

# %%
# GRÁFICO DE BARRAS COMPARATIVO.
# Ímpares.
x1 = [1, 3, 5, 7, 9];
y1 = [3, 6, 2, 1, 4];

# Pares.
x2 = [2, 4, 6, 8, 10];
y2 = [5, 1, 3, 7, 4];

# Legendas.
plt.title("Gráfico de Barras");

plt.xlabel("Eixo X");
plt.ylabel("Eixo Y");

# Plotando o gráfico de barras.
plt.bar(x, y, label = "Grupo 1");
plt.bar(x2, y2, label = "Grupo 2");

# Mostrando as labels.
plt.legend();

plt.show();

# %%
# SCATTERPLOT (GRÁFICOS DE PONTOS)

x = [1, 3, 5, 7, 9];
y = [3, 6, 2, 1, 4];

# Legendas.
plt.title("Gráfico de Pontos");

plt.xlabel("Eixo X");
plt.ylabel("Eixo Y");

# Plotando o gráfico de pontos.
# Podemos customizar os atributos: cor, tamanho, formato, tipo de linha e etc. 
plt.scatter(x, y, label = "Meus Pontos", color = "R");

# Plotando linhas que ligam os pontos.
plt.plot(x, y);

# Mostrando da label.
plt.legend();

# Mostrando o gráfico.
plt.show();

# %% [markdown]
# DOCS
#
# color:	cor (ver exemplos abaixo)<br>
# label:	rótulo<br>
# linestyle:	estilo de linha (ver exemplos abaixo)<br>
# linewidth: largura da linha<br>
# marker:	marcador (ver exemplos abaixo)<br>
# <br>
# CORES (color)<br>
# 'b'	blue<br>
# 'g'	green<br>
# 'r'	red<br>
# 'c'	cyan<br>
# 'm'	magenta<br>
# 'y'	yellow<br>
# 'k'	black<br>
# 'w'	white<br>
# <br>
# Marcadores (marker)<br>
# '.'	point marker<br>
# ','	pixel marker<br>
# 'o'	circle marker<br>
# 'v'	triangle_down marker<br>
# '^'	triangle_up marker<br>
# '<'	triangle_left marker<br>
# '>'	triangle_right marker<br>
# '1'	tri_down marker<br>
# '2'	tri_up marker<br>
# '3'	tri_left marker<br>
# '4'	tri_right marker<br>
# 's'	square marker<br>
# 'p'	pentagon marker<br>
# '*'	star marker<br>
# 'h'	hexagon1 marker<br>
# 'H'	hexagon2 marker<br>
# '+'	plus marker<br>
# 'x'	x marker<br>
# 'D'	diamond marker<br>
# 'd'	thin_diamond marker<br>
# '|'	vline marker<br>
# '_'	hline marker<br>
#
# <br>
# Tipos de linha (linestyle)<br>
# '-'	solid line style<br>
# '--'	dashed line style<br>
# '-.'	dash-dot line style<br>
# ':'	dotted line style<br>

# %%
# PRA SALVAR UM GRAFICO USAMOS O COMANDO
# plt.savefig("NomeDaFigura.pdf");
# ou
# plt.savefig("NomeDaFigura.png", dpi = 1200)
